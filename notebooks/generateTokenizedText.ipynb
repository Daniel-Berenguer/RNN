# %%
import sys
import os

# Add the root directory to the system path
root_path = os.path.abspath(os.path.join(".."))
if root_path not in sys.path:
    sys.path.append(root_path)

from src.tokenizer import Tokenizer

tokenizer = Tokenizer()
tokenizer.load()

# %%
import torch
import torch.nn.functional as F
from src.modelTokenized import Model


HSIZE = 128
SEQUENCE_LENGTH = 30

model = Model(tokenizer.N, HSIZE)

# %%
with open("../model_weights_tokenized", "rb") as file:
    model.load_state_dict(torch.load(file))

# %%
print(model.gru.bN_u.runningMean)
# Out:
# Parameter containing:
# tensor([ -30.4089,  -80.0266,  -26.7948,  -49.0246,  -94.4079,  -53.6148,
#          -34.6053,  -44.0101,  -54.3059,  -48.9706,  -25.2879,  -59.6890,
#          -47.9147,  -34.7455,  -86.0674,  -48.8964, -127.9646,  -75.2269,
#          -13.7266,  -42.8818,  -25.8266,  -51.7554,  -48.5940,  -15.2906,
#         -117.0929, -105.1198,  -43.1326,  -64.5696,  -53.4824,  -30.3757,
#          -98.9775,  -82.2478, -109.3255,  -51.0680,  -11.0687,  -73.8882,
#           -7.4569,  -99.1451, -148.4676,  -45.7623,  -93.8075,  -36.0474,
#          -52.2784,  -58.9071,  -11.3402,  -47.0831,  -15.2010,  -50.4270,
#          -46.1610,  -42.2677,  -23.9342, -105.1030,  -73.9310, -106.9341,
#          -51.1147,    9.2089,  -13.9579,  -74.1559, -101.7168,  -69.1680,
#          -46.2908,  -94.2295,  -76.7574,  -47.2658, -146.3714,  -69.7924,
#          -88.2510, -108.0595,  -33.9888, -103.3003,  -45.8423,    7.8727,
#          -14.8264,  -37.8998,  -37.1361,  -55.3104,  -41.1776,  -13.2928,
#          -44.9923,  -67.3368,   -5.9499,  -45.6989,  -20.5934,  -39.7611,
#          -37.4296,  -20.7352,  -93.3358,  -44.1181,   10.9238,  -61.0573,
#          -37.6236,  -10.7258,   19.0595,  -92.1195,  -90.9357,  -37.8287,
#         -156.8951,  -84.3117, -157.3987,  -74.0241,  -68.9740,  -10.5882,
#           -7.1027,  -81.6875,  -17.7716,  -50.0326,  -44.8162,  -42.8782,
#          -61.4679,   -1.4644,  -67.8310,  -66.1799,  -39.5706,    6.7330,
#          -86.8230,  -76.2243,  -58.3987,   -2.1755,  -64.2043, -146.9244,
#          -65.9536,  -73.1082, -109.3285,  -25.6724,   80.3873,    0.3315,
#          -23.6498,  -45.6242])

# %%
tokenizer.chars_to_tokens[" "]
# Out:
# 0

# %%
def generate_char(tokens):
    logits = model.forward(tokens, train=False)
    probs = F.softmax(logits, dim=1)
    generated = torch.multinomial(probs, 1).item()
    new_char = tokenizer.tokens_to_chars[generated]
    return generated, new_char

# %%
def generate_text(text, num):
    tokens = tokenizer.encode(text)
    if len(tokens) > SEQUENCE_LENGTH:
        tokens = tokens[:SEQUENCE_LENGTH]
        print("WARNING: Trunkating")
    tokens = [0] * (SEQUENCE_LENGTH - len(tokens)) + tokens
    tokens = torch.tensor(tokens).reshape(1, -1)
    for i in range(num):
        token, new_char = generate_char(tokens)
        text += new_char
        tokens = torch.roll(tokens, -1, 1)
        tokens[0][-1] = token

    print(text)

# %%
a = [1,2,3]
a = [5] * (5-len(a)) + a
a
# Out:
# [5, 5, 1, 2, 3]

# %%
generate_text("the stock went down after it", 50)
# Out:
# 46
# 50
# 53
# 60
# 66
# 70
# 76
# 86
# 114
# 119
# 129
# 140
# 159
# 221
# 232
# 260
# 296
# 422
# 464
# 644
# 875
# the stock went down after ity
#  mr. steice said he is n't chance it to the national neti even great and make apard the search face to favor court  the programs which lynon there are so  that does n't get any

# %%
import numpy as np

with open("../data/X_test", "rb") as file:
    seq = np.load(file)

# %%
tokenizer.chars_to_tokens
# Out:
# {' ': 0,
#  'a': 1,
#  'e': 2,
#  'r': 3,
#  'b': 4,
#  'n': 5,
#  'k': 6,
#  'o': 7,
#  't': 8,
#  'l': 9,
#  'i': 10,
#  'z': 11,
#  'c': 12,
#  'w': 13,
#  'y': 14,
#  'u': 15,
#  's': 16,
#  'f': 17,
#  'm': 18,
#  'g': 19,
#  'h': 20,
#  'd': 21,
#  '-': 22,
#  'q': 23,
#  'p': 24,
#  'x': 25,
#  '\n': 26,
#  'j': 27,
#  'v': 28,
#  '.': 29,
#  "'": 30,
#  '1': 31,
#  '9': 32,
#  '5': 33,
#  '0': 34,
#  '&': 35,
#  'V': 36,
#  '3': 37,
#  '2': 38,
#  '$': 39,
#  '4': 40,
#  '8': 41,
#  '6': 42,
#  '7': 43,
#  '#': 44,
#  '|': 45,
#  'e ': 46,
#  's ': 47,
#  ' t': 48,
#  'in': 49,
#  't ': 50,
#  ' th': 51,
#  'd ': 52,
#  'er': 53,
#  'an': 54,
#  'on': 55,
#  ' the ': 56,
#  'or': 57,
#  'y ': 58,
#  'ar': 59,
#  'en': 60,
#  'al': 61,
#  'o ': 62,
#  '\n ': 63,
#  're': 64,
#  'of': 65,
#  'th': 66,
#  'ti': 67,
#  'a ': 68,
#  'ing': 69,
#  'st': 70,
#  'ou': 71,
#  'on ': 72,
#  'es ': 73,
#  'om': 74,
#  'ed ': 75,
#  'er ': 76,
#  'il': 77,
#  'at': 78,
#  'ing ': 79,
#  'of ': 80,
#  'ic': 81,
#  'and ': 82,
#  'in ': 83,
#  'li': 84,
#  ' to ': 85,
#  'it': 86,
#  'ro': 87,
#  'as ': 88,
#  'ch': 89,
#  '. ': 90,
#  'for': 91,
#  'al ': 92,
#  'ec': 93,
#  'el': 94,
#  'is ': 95,
#  'at ': 96,
#  'an ': 97,
#  'as': 98,
#  'sa': 99,
#  'es': 100,
#  'ed': 101,
#  'com': 102,
#  ' m': 103,
#  'ur': 104,
#  "'s ": 105,
#  'l ': 106,
#  'ac': 107,
#  'si': 108,
#  'ear': 109,
#  'sh': 110,
#  'ad': 111,
#  'ts ': 112,
#  'wh': 113,
#  'ent ': 114,
#  'bu': 115,
#  'ati': 116,
#  'it ': 117,
#  '  ': 118,
#  'ow': 119,
#  've ': 120,
#  'ir': 121,
#  'ex': 122,
#  'em': 123,
#  'ag': 124,
#  'un': 125,
#  'ol': 126,
#  'su': 127,
#  'to ': 128,
#  'k ': 129,
#  'ly ': 130,
#  'is': 131,
#  'pro': 132,
#  'ers ': 133,
#  'con': 134,
#  '\n the ': 135,
#  'am': 136,
#  'os': 137,
#  'illi': 138,
#  'fr': 139,
#  'the ': 140,
#  'illion ': 141,
#  'pl': 142,
#  'id ': 143,
#  'are ': 144,
#  'ne': 145,
#  ' \n ': 146,
#  'gh': 147,
#  'id': 148,
#  'ha': 149,
#  'ver': 150,
#  'for ': 151,
#  'comp': 152,
#  'ith': 153,
#  'ab': 154,
#  ' b': 155,
#  'of the ': 156,
#  'with': 157,
#  'ri': 158,
#  'oc': 159,
#  'en ': 160,
#  'ap': 161,
#  'de': 162,
#  'qu': 163,
#  ' c': 164,
#  ' that ': 165,
#  'us': 166,
#  'ay ': 167,
#  'from': 168,
#  'in the ': 169,
#  'its ': 170,
#  'se': 171,
#  'ce ': 172,
#  'r. ': 173,
#  'be': 174,
#  'di': 175,
#  'op': 176,
#  'ate ': 177,
#  'said ': 178,
#  'any ': 179,
#  'and': 180,
#  'or ': 181,
#  'le': 182,
#  'year': 183,
#  'ak': 184,
#  'pre': 185,
#  'ld ': 186,
#  'est': 187,
#  'pr': 188,
#  'du': 189,
#  'be ': 190,
#  'was ': 191,
#  'ter': 192,
#  'ons ': 193,
#  'ere ': 194,
#  'et ': 195,
#  'le ': 196,
#  'inc': 197,
#  'ould ': 198,
#  'V m': 199,
#  'p ': 200,
#  ' the': 201,
#  'ill ': 202,
#  'he ': 203,
#  'oun': 204,
#  'sp': 205,
#  'ent': 206,
#  'off': 207,
#  'tion ': 208,
#  'mr. ': 209,
#  'w ': 210,
#  'ation ': 211,
#  'im': 212,
#  'has ': 213,
#  'V million ': 214,
#  "n'": 215,
#  'ed to ': 216,
#  'ment ': 217,
#  'tr': 218,
#  'str': 219,
#  's \n ': 220,
#  'ter ': 221,
#  'by ': 222,
#  'mar': 223,
#  'par': 224,
#  'have ': 225,
#  'por': 226,
#  "n't ": 227,
#  ' to': 228,
#  'out ': 229,
#  ' tr': 230,
#  'oth': 231,
#  'n ': 232,
#  'will ': 233,
#  ' a ': 234,
#  'ge ': 235,
#  'rec': 236,
#  'vi': 237,
#  'no': 238,
#  'ys ': 239,
#  'ich': 240,
#  'our': 241,
#  'ain': 242,
#  'gr': 243,
#  'ul': 244,
#  'ch ': 245,
#  'but ': 246,
#  'et': 247,
#  'one ': 248,
#  'ents ': 249,
#  'go': 250,
#  'ds ': 251,
#  'company ': 252,
#  'est ': 253,
#  'po': 254,
#  'um': 255,
#  'from ': 256,
#  'inv': 257,
#  ' and ': 258,
#  'ore ': 259,
#  'stoc': 260,
#  'cl': 261,
#  'se ': 262,
#  'mark': 263,
#  'ity ': 264,
#  'which': 265,
#  'ig': 266,
#  'new ': 267,
#  'igh': 268,
#  'ast ': 269,
#  'if': 270,
#  'per': 271,
#  'at the ': 272,
#  'comm': 273,
#  'ome ': 274,
#  'sid': 275,
#  'so ': 276,
#  'cor': 277,
#  'wor': 278,
#  'we': 279,
#  'all': 280,
#  'ice ': 281,
#  'ut': 282,
#  'that ': 283,
#  'would ': 284,
#  'ev': 285,
#  'ci': 286,
#  'ough': 287,
#  'lo': 288,
#  'mon': 289,
#  'with ': 290,
#  's. ': 291,
#  'fir': 292,
#  'age ': 293,
#  'ted ': 294,
#  'ks ': 295,
#  'af': 296,
#  'bl': 297,
#  ' this ': 298,
#  'st ': 299,
#  'day ': 300,
#  'all ': 301,
#  'end': 302,
#  'to': 303,
#  'sec': 304,
#  'ess ': 305,
#  'duc': 306,
#  'ong': 307,
#  'ud': 308,
#  'were ': 309,
#  'fin': 310,
#  'sin': 311,
#  'ef': 312,
#  'onal ': 313,
#  'ors ': 314,
#  'on the ': 315,
#  ' they ': 316,
#  'for the ': 317,
#  'u.': 318,
#  'es \n ': 319,
#  ' of ': 320,
#  'other ': 321,
#  'tic': 322,
#  'inter': 323,
#  'ake ': 324,
#  'invest': 325,
#  'chan': 326,
#  'ay': 327,
#  'his ': 328,
#  'which ': 329,
#  'res': 330,
#  'ban': 331,
#  'cont': 332,
#  'shar': 333,
#  'ost ': 334,
#  'sal': 335,
#  'says ': 336,
#  'year ': 337,
#  'about ': 338,
#  'co': 339,
#  'exp': 340,
#  'ations ': 341,
#  'ally ': 342,
#  'ing the ': 343,
#  'air': 344,
#  'ow ': 345,
#  'had ': 346,
#  'use ': 347,
#  'au': 348,
#  'some ': 349,
#  'man ': 350,
#  'reas': 351,
#  'u.s. ': 352,
#  'more ': 353,
#  'said': 354,
#  'ies ': 355,
#  'ings ': 356,
#  'ance ': 357,
#  'dec': 358,
#  'who ': 359,
#  ' trad': 360,
#  'pe': 361,
#  'lin': 362,
#  'min': 363,
#  'share ': 364,
#  ' their': 365,
#  'mo': 366,
#  ' billion ': 367,
#  't the ': 368,
#  'y the ': 369,
#  'ure ': 370,
#  'also ': 371,
#  'bo': 372,
#  'th ': 373,
#  'ed the ': 374,
#  'iti': 375,
#  'sel': 376,
#  'ard ': 377,
#  'ma': 378,
#  'ing to ': 379,
#  'sion ': 380,
#  'market ': 381,
#  'und': 382,
#  'lar': 383,
#  'pu': 384,
#  'a  ': 385,
#  'ea': 386,
#  'V billion ': 387,
#  'sts ': 388,
#  'produc': 389,
#  'tim': 390,
#  'i ': 391,
#  'bec': 392,
#  'ose ': 393,
#  'la': 394,
#  'we ': 395,
#  'wo ': 396,
#  'ser': 397,
#  'vel': 398,
#  'm ': 399,
#  'p. ': 400,
#  'tions ': 401,
#  'eral ': 402,
#  'quar': 403,
#  'man': 404,
#  'ue ': 405,
#  'ic ': 406,
#  'busin': 407,
#  'als ': 408,
#  'ber ': 409,
#  'coun': 410,
#  'e the ': 411,
#  'plan': 412,
#  'presid': 413,
#  'ver ': 414,
#  'ust ': 415,
#  'offic': 416,
#  ' to the ': 417,
#  'ey ': 418,
#  'able ': 419,
#  'old': 420,
#  'ated ': 421,
#  'stock ': 422,
#  'ple ': 423,
#  'high': 424,
#  'low': 425,
#  'tive ': 426,
#  'ause ': 427,
#  'fac': 428,
#  'ement ': 429,
#  'been ': 430,
#  'ta': 431,
#  'ates ': 432,
#  'up ': 433,
#  'not ': 434,
#  'nati': 435,
#  't to ': 436,
#  'ese ': 437,
#  'own': 438,
#  'anc': 439,
#  'ary ': 440,
#  'president ': 441,
#  'gen': 442,
#  'sti': 443,
#  'pos': 444,
#  'dis': 445,
#  'last ': 446,
#  'and the ': 447,
#  ' their ': 448,
#  'sur': 449,
#  'ure': 450,
#  'e \n ': 451,
#  'form': 452,
#  'gi': 453,
#  'up': 454,
#  'y to ': 455,
#  'oper': 456,
#  'ep': 457,
#  'ting ': 458,
#  'expec': 459,
#  'old ': 460,
#  " 's ": 461,
#  'repor': 462,
#  'over': 463,
#  'own ': 464,
#  'tur': 465,
#  'pric': 466,
#  'ill': 467,
#  'wee': 468,
#  'me': 469,
#  'sen': 470,
#  'indu': 471,
#  'new': 472,
#  'ip': 473,
#  'quarter ': 474,
#  'fe': 475,
#  'issu': 476,
#  'grou': 477,
#  'shares ': 478,
#  'so': 479,
#  'part': 480,
#  'ell ': 481,
#  'uc': 482,
#  'ra': 483,
#  'sales ': 484,
#  'inc. ': 485,
#  'change ': 486,
#  'ed by ': 487,
#  'od ': 488,
#  'years ': 489,
#  'cer': 490,
#  'most ': 491,
#  'fi': 492,
#  'compan': 493,
#  'first ': 494,
#  'jo': 495,
#  'ind': 496,
#  'eric': 497,
#  'row': 498,
#  'prov': 499,
#  'in a ': 500,
#  'bon': 501,
#  'increas': 502,
#  'gover': 503,
#  'because ': 504,
#  'ack': 505,
#  'tt': 506,
#  'yor': 507,
#  'V ': 508,
#  'govern': 509,
#  'national ': 510,
#  'br': 511,
#  'fl': 512,
#  'ves ': 513,
#  'ities ': 514,
#  'new yor': 515,
#  'jap': 516,
#  'ar ': 517,
#  'ong ': 518,
#  'lik': 519,
#  'pres': 520,
#  'do': 521,
#  'prof': 522,
#  'americ': 523,
#  'from the ': 524,
#  'spec': 525,
#  'lud': 526,
#  'att': 527,
#  'econ': 528,
#  'econom': 529,
#  'includ': 530,
#  'hou': 531,
#  'do ': 532,
#  'said it ': 533,
#  'fed': 534,
#  'with the ': 535,
#  'ann': 536,
#  'ester': 537,
#  'da': 538,
#  'ely ': 539,
#  'could ': 540,
#  't of ': 541,
#  'out': 542,
#  'urr': 543,
#  'ia ': 544,
#  's to ': 545,
#  'er \n ': 546,
#  'hel': 547,
#  'earn': 548,
#  'business ': 549,
#  'hold': 550,
#  'int': 551,
#  'ree ': 552,
#  'aly': 553,
#  'ual ': 554,
#  'serv': 555,
#  'sub': 556,
#  'whil': 557,
#  'ok': 558,
#  'ash': 559,
#  'em ': 560,
#  'exec': 561,
#  'enc': 562,
#  'many ': 563,
#  ' there ': 564,
#  'ess': 565,
#  'analy': 566,
#  's of ': 567,
#  'ed a ': 568,
#  'secur': 569,
#  'ven': 570,
#  'sy': 571,
#  'los': 572,
#  'end ': 573,
#  'than ': 574,
#  'bas': 575,
#  'e of ': 576,
#  'said the ': 577,
#  'gu': 578,
#  'sul': 579,
#  'corp. ': 580,
#  'only ': 581,
#  'gram': 582,
#  'fun': 583,
#  'execu': 584,
#  'federal ': 585,
#  'ord': 586,
#  'month': 587,
#  'big': 588,
#  'ence ': 589,
#  'no ': 590,
#  'over ': 591,
#  'ed in ': 592,
#  'cial ': 593,
#  'program': 594,
#  'government ': 595,
#  ' that the ': 596,
#  ' mar': 597,
#  'cre': 598,
#  'offici': 599,
#  'he': 600,
#  'new york ': 601,
#  'ant ': 602,
#  'son ': 603,
#  'ell': 604,
#  'ures ': 605,
#  'iz': 606,
#  'stri': 607,
#  'mak': 608,
#  'will be ': 609,
#  'peo': 610,
#  'ite ': 611,
#  'sh ': 612,
#  'car': 613,
#  'ain ': 614,
#  'exchange ': 615,
#  'people ': 616,
#  'ble ': 617,
#  'y \n ': 618,
#  'by the ': 619,
#  'companies ': 620,
#  'pri': 621,
#  'enti': 622,
#  'you': 623,
#  'ets ': 624,
#  'te': 625,
#  'cap': 626,
#  'ough ': 627,
#  'earli': 628,
#  'and  ': 629,
#  'ris': 630,
#  'qui': 631,
#  'ber': 632,
#  'ine ': 633,
#  'fer': 634,
#  'direc': 635,
#  'ass': 636,
#  'can ': 637,
#  'gn': 638,
#  'el ': 639,
#  'chi': 640,
#  'ed \n ': 641,
#  'trad': 642,
#  'price ': 643,
#  'after ': 644,
#  'ous ': 645,
#  'of  ': 646,
#  'said \n ': 647,
#  'ating ': 648,
#  'char': 649,
#  ' two ': 650,
#  'red ': 651,
#  'ad ': 652,
#  'king ': 653,
#  'may ': 654,
#  'pp': 655,
#  'me ': 656,
#  'contin': 657,
#  'V a ': 658,
#  'clos': 659,
#  'rose ': 660,
#  'our ': 661,
#  'group ': 662,
#  'bank ': 663,
#  'manag': 664,
#  'e-': 665,
#  'buy': 666,
#  'lat': 667,
#  ' tim': 668,
#  'ight ': 669,
#  ' trading ': 670,
#  'col': 671,
#  'ack ': 672,
#  'finan': 673,
#  'yester': 674,
#  'such ': 675,
#  'ty ': 676,
#  'prices ': 677,
#  'ans ': 678,
#  'il ': 679,
#  'mr.  ': 680,
#  'trac': 681,
#  'law': 682,
#  'eg': 683,
#  'when ': 684,
#  'ph': 685,
#  'war': 686,
#  'fa': 687,
#  'll ': 688,
#  '\n but ': 689,
#  'cr': 690,
#  'agre': 691,
#  'while ': 692,
#  'how': 693,
#  'come ': 694,
#  'investors ': 695,
#  'val': 696,
#  'dem': 697,
#  'publ': 698,
#  'to the ': 699,
#  'bro': 700,
#  'ot': 701,
#  'very ': 702,
#  'state ': 703,
#  'nex': 704,
#  'maj': 705,
#  'on to ': 706,
#  'if ': 707,
#  'ago ': 708,
#  'rate ': 709,
#  'leg': 710,
#  'dr': 711,
#  ' mark': 712,
#  ' co': 713,
#  'million ': 714,
#  'into ': 715,
#  'des': 716,
#  'poin': 717,
#  'x ': 718,
#  'get ': 719,
#  'now ': 720,
#  't \n ': 721,
#  'interest ': 722,
#  'ments ': 723,
#  'ase ': 724,
#  'ade ': 725,
#  'pol': 726,
#  'curr': 727,
#  'say': 728,
#  'grow': 729,
#  'securities ': 730,
#  'uni': 731,
#  'iel': 732,
#  'ly': 733,
#  'chair': 734,
#  'ently ': 735,
#  'deb': 736,
#  'ital ': 737,
#  'what ': 738,
#  'ort': 739,
#  ' mr. ': 740,
#  'but': 741,
#  'cour': 742,
#  'cu': 743,
#  'declin': 744,
#  'tu': 745,
#  "it 's ": 746,
#  'od': 747,
#  'ef ': 748,
#  'oci': 749,
#  'sum': 750,
#  'mu': 751,
#  'ach': 752,
#  'sign': 753,
#  'ex ': 754,
#  'chairman ': 755,
#  'jec': 756,
#  'ond': 757,
#  'direct': 758,
#  'resul': 759,
#  'V a share ': 760,
#  'port': 761,
#  'gre': 762,
#  'ther ': 763,
#  'syst': 764,
#  'ems ': 765,
#  'offer': 766,
#  'sm': 767,
#  'pur': 768,
#  'stock': 769,
#  'week ': 770,
#  'nor': 771,
#  'bet': 772,
#  'struc': 773,
#  'not': 774,
#  'under': 775,
#  'industr': 776,
#  'yesterday ': 777,
#  'earnings ': 778,
#  'ed that ': 779,
#  'it is ': 780,
#  'house ': 781,
#  'as a ': 782,
#  'gres': 783,
#  'ound ': 784,
#  'elec': 785,
#  'executive ': 786,
#  'fo': 787,
#  'ing a ': 788,
#  '\n in ': 789,
#  'en the ': 790,
#  'pt': 791,
#  'next ': 792,
#  'fic': 793,
#  'devel': 794,
#  'develop': 795,
#  'did ': 796,
#  'american ': 797,
#  'fil': 798,
#  'yiel': 799,
#  'financial ': 800,
#  'net ': 801,
#  'ste': 802,
#  'since ': 803,
#  'equ': 804,
#  'investment ': 805,
#  'wa': 806,
#  'cal': 807,
#  'mer': 808,
#  'ical ': 809,
#  ' in ': 810,
#  '  \n ': 811,
#  'ide ': 812,
#  'righ': 813,
#  'buil': 814,
#  'way ': 815,
#  'now': 816,
#  'eng': 817,
#  'stand': 818,
#  'firm': 819,
#  'early ': 820,
#  'contrac': 821,
#  'ember ': 822,
#  'fut': 823,
#  'concer': 824,
#  'mini': 825,
#  'f ': 826,
#  'make ': 827,
#  "company 's ": 828,
#  'pa': 829,
#  'alth': 830,
#  'ing \n ': 831,
#  'ame ': 832,
#  'chief ': 833,
#  'you ': 834,
#  'fec': 835,
#  'ges ': 836,
#  'japan': 837,
#  'of a ': 838,
#  'dol': 839,
#  'officials ': 840,
#  'stocks ': 841,
#  'us ': 842,
#  ' by ': 843,
#  '\n th': 844,
#  'eu': 845,
#  'bonds ': 846,
#  'call': 847,
#  'she ': 848,
#  'plo': 849,
#  'sch': 850,
#  'main': 851,
#  'lead': 852,
#  'stor': 853,
#  'again': 854,
#  'analysts ': 855,
#  'verage ': 856,
#  'adv': 857,
#  'contro': 858,
#  'probl': 859,
#  'ury ': 860,
#  'ed at ': 861,
#  'or c': 862,
#  ' \n the ': 863,
#  'dollar': 864,
#  'insur': 865,
#  'like ': 866,
#  'still ': 867,
#  'ug': 868,
#  'add': 869,
#  'just ': 870,
#  'cent': 871,
#  'for a ': 872,
#  'ily ': 873,
#  'vid': 874,
#  'down ': 875,
#  'ang': 876,
#  'ents a ': 877,
#  ' than ': 878,
#  'they ': 879,
#  'japanese ': 880,
#  'kers ': 881,
#  'pay': 882,
#  'propos': 883,
#  'vol': 884,
#  'isc': 885,
#  's and ': 886,
#  'read': 887,
#  'sell': 888,
#  'after': 889,
#  'reven': 890,
#  'products ': 891,
#  'does ': 892,
#  'work ': 893,
#  'less ': 894,
#  'ther': 895,
#  'estim': 896,
#  ' market ': 897,
#  'industry ': 898,
#  'ard': 899,
#  're ': 900,
#  'accor': 901,
#  'sept': 902,
#  'hea': 903,
#  'ign': 904,
#  'og': 905,
#  'dur': 906,
#  'congres': 907,
#  'larg': 908,
#  "' ": 909,
#  'where ': 910,
#  'pac': 911,
#  'emplo': 912,
#  'ants ': 913,
#  'reg': 914,
#  'cri': 915,
#  'compl': 916,
#  'ties ': 917,
#  'well ': 918,
#  'ant': 919,
#  'with a ': 920,
#  'rates ': 921,
#  'posi': 922,
#  'acc': 923,
#  'divid': 924,
#  'profit ': 925,
#  'depart': 926,
#  ' thr': 927,
#  'even ': 928,
#  'rel': 929,
#  'jun': 930,
#  'dro': 931,
#  'more than ': 932,
#  'ses ': 933,
#  'of its ': 934,
#  'industri': 935,
#  'spok': 936,
#  'revenue ': 937,
#  'commit': 938,
#  'peri': 939,
#  'gain': 940,
#  'ise ': 941,
#  'expect': 942,
#  'ers \n ': 943,
#  'compu': 944,
#  'as the ': 945,
#  'vie': 946,
#  'ever ': 947,
#  'befor': 948,
#  'general ': 949,
#  'long': 950,
#  'would be ': 951,
#  ' ta': 952,
#  ' more ': 953,
#  'recent ': 954,
#  'tain': 955,
#  'employ': 956,
#  ' three ': 957,
#  ' mon': 958,
#  'sou': 959,
#  'unit ': 960,
#  'average ': 961,
#  'ok ': 962,
#  'proc': 963,
#  'asse': 964,
#  'poli': 965,
#  'mil': 966,
#  ' co. ': 967,
#  'ents a share ': 968,
#  ' is ': 969,
#  'sup': 970,
#  "do n't ": 971,
#  'stre': 972,
#  'her ': 973,
#  ' those ': 974,
#  'time ': 975,
#  'ative ': 976,
#  'fore': 977,
#  'num': 978,
#  'but the ': 979,
#  'purch': 980,
#  'spokes': 981,
#  'down': 982,
#  'under ': 983,
#  '\n they ': 984,
#  '& ': 985,
#  'sever': 986,
#  'av': 987,
#  'cc': 988,
#  'acqui': 989,
#  'ob': 990,
#  'both': 991,
#  'much ': 992,
#  'accord': 993,
#  'beg': 994,
#  'ounc': 995,
#  'lim': 996,
#  'index ': 997,
#  'ger': 998,
#  'vision ': 999,
#  ...}
